# %% [markdown]
# <h1 align='center'>Support Vector Machines</h1>

# %% [markdown]
# SVM's are a powerful class of supervised learning algorithms for classification and regression problems. In the context of classification, SVM's can be viewed as maximum margin linear classifiers.

# %% [markdown]
# The SVM uses an objective which explicitly encourages low-out-of-sample error(good generalization performance). The $D$ dimensional data are divided into classes by maximizing the margin between the hyperplanes for the classes.

# %% [markdown]
# Note that we assume the two classes in the data are linearly sepaerable. Later, for non linear boundaries, we will use thee kernel trick to exploit higher(possibly infinite) dimensional $z$-spaces, where the classes are linearly seperable, find the support vectors in this space and map it back to the dimensionality of our problem.

# %% [markdown]
# ## Linear seperable classes:

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# use seaborn plotting defaults
import seaborn as sns; sns.set()

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y = make_blobs(n_samples=50, centers=2,
                 random_state=0, cluster_std=0.60)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer');

# %% [markdown]
# The linear classifiers we know will draw a straight line between the classes. With this example, we could do this by hand. But what should strike you is that there is more than one decision boundary that can achieve maximum in-sample error. Let's plot them below.

# %% [markdown]
# ## Many possible seperators:

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer')
plt.plot([0.6], [2.1], 'x', color='green', markeredgewidth=2, markersize=10)

for m, b in [(1,0.65),(0.5, 1.6), (-0.2,2.9)]:
    plt.plot(xfit, m*xfit + b, '-k')

plt.xlim(-1, 3.5);

# %% [markdown]
# ## Maximum margin linear classifiers:

# %% [markdown]
# For a hyperplane defined by weight $w$ and bias $b$, a linear discriminat is given by:

# %% [markdown]
# $$w^T x + b \left\{\begin{matrix} \geq 0\ class +1& \\ <0\ class -1 \end{matrix}\right.$$

# %% [markdown]
# In the above plot, we note that for a point $x$ that is close to the decision boundary at $w^T x+b=0$, a small change in $x$ can lead to change in classification. Now assuming that the data is linearly seperable, we impose that for the training data, the decision boundary should be seperated from the data by some finite amount $\epsilon ^2$:

# %% [markdown]
# $$w^T x + b \left\{\begin{matrix} \geq \epsilon^2\ class +1& \\ <\epsilon^2\ class -1 \end{matrix}\right.$$

# %% [markdown]
# For the inequality above, we conviniently set $\epsilon=1$ so that a point $x_+$ from class +1 that is closest to the decision boundary satisfies

# %% [markdown]
# $$w^T x_+ + b =1$$

# %% [markdown]
# and a point $x_-$ from class -1 that is closest to the decision boundaty satisfies

# %% [markdown]
# $$w^T x_- + b =1$$

# %% [markdown]
# ## Plotting the margins:

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer')

for m, b, d in [(1,0.65,0.33),(0.5, 1.6, 0.55), (-0.2,2.9,0.2)]:
    yfit = m * xfit +b
    plt.plot(xfit, m*xfit + b, '-k')
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',
                    color='#AAAAAA', alpha=0.4)

plt.xlim(-1, 3.5);

# %% [markdown]
# When using SVM's, the decision boundary that maximizes this margin is chosen as optimal model.

# %% [markdown]
# ## SVM in practice:

# %%
from sklearn.svm import SVC # "Support vector classifier"
model = SVC(kernel='linear', C=1E10)
model.fit(X, y)
# Out:
# SVC(C=10000000000.0, break_ties=False, cache_size=200, class_weight=None,
#     coef0=0.0, decision_function_shape='ovr', degree=3, gamma='scale',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## Visualizing the SVM decision boundaries:

# %%
def plot_svc_decision_function(model, ax=None, plot_support=True):
    """Plot the decision function for a 2D SVC"""
    if ax is None:
        ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    #create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 30)
    y = np.linspace(ylim[0], ylim[1], 30)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([[X.ravel(), Y.ravel()]]).T
    P = model.decision_function(xy).reshape(X.shape)
    
    #plot decision boundary and margins
    ax.contour(X, Y, P, colors='k',
               levels=[-1,0,1], alpha=0.5,
              linestyles=['--','-','--'])
    
    #plot support vectors
    if plot_support:
        ax.scatter(model.support_vectors_[:,0],
                  model.support_vectors_[:, 1],
                  s=300, linewidth=1, facecolors='none');
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer')
plot_svc_decision_function(model);

# %% [markdown]
# The bold line dividing the data maximizes the margin between the two sets of points. Count the number of training points just touching the margin. These points are known as `support vectors_`. These points exactly satisfying the margin are stored in the `support_vectors_` attribute of the classifier in the Scikit-Learn.

# %%
model.support_vectors_
# Out:
# array([[0.44359863, 3.11530945],
#        [2.33812285, 3.43116792],
#        [2.06156753, 1.96918596]])

# %% [markdown]
# ## Discussion:

# %% [markdown]
# In the hard-margin SVM classifier, only the position of the support vectors matter. Points away from the margin which are not on the correct side don't change the fit. This is because these points do not contribute to the loss function used to fit the model.

# %%
def plot_svm(N=10, ax=None):
    X, y = make_blobs(n_samples=200, centers=2,
                     random_state=0, cluster_std=0.60)
    X = X[:N]
    y = y[:N]
    model = SVC(kernel='linear', C=1E10)
    model.fit(X, y)
    
    ax = ax or plt.gca()
    ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='summer')
    ax.set_xlim(-1,4)
    ax.set_ylim(-1,6)
    plot_svc_decision_function(model, ax)

fig, ax = plt.subplots(1, 2, figsize=(16,6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)
for axi, N in zip(ax, [60, 120]):
    plot_svm(N, axi)
    axi.set_title('N={0}'.format(N))

# %% [markdown]
# In the left panel, we see the model and the support vectors for 60 training points. In the right panel, we have doubled the number of training points, but the model has not changed: the three support vectors from the left panel are still the support vectors from the right panel. This insensitivity to the exact behaviour of the distant points is one of the strengths of the SVM model.

# %% [markdown]
# ## Interactive Visualization:

# %%
from ipywidgets import interact, fixed
interact(plot_svm, N=(10, 200, 10), ax=fixed(None));
# Out:
# interactive(children=(IntSlider(value=10, description='N', max=200, min=10, step=10), Output()), _dom_classes=…

# %% [markdown]
# ## The Kernel trick and non-linear boundaries:

# %% [markdown]
# In working with linear algebra and linear regression, we have come across a version of kernels before, in the form of basis functions. We use a similar approach with kernels, where our data is projected into a higher-dimensional space $\Re^d$ defined by a polynomial $\Phi$ of order $\mathbb(Q)$ and a basis function, and thereby fit nonlinear relationships with a linear classifier.

# %% [markdown]
# Let's now plot some data that is not linearly seperable:

# %%
from sklearn.datasets.samples_generator import make_circles
X, y = make_circles(100, factor=.1, noise=.1)

clf = SVC(kernel='linear').fit(X,y)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer')
plot_svc_decision_function(clf, plot_support=False);

# %% [markdown]
# On running the cell couple of times, I think that you can tell that there is no linear decision boundary that will ever be able to seperate the data. Here is where kernels come in handy. We can project our data into a hogh dimensional space where there exists a linear seperator. One widely used projection is computed using a radial basis function centered on the middle clump.

# %%
r = np.exp(-(X**2).sum(1))

# %% [markdown]
# ## Visualizing higher-dimensional projections:

# %%
from mpl_toolkits import mplot3d

def plot_3D(elev=30, azim=30, X=X, y=y):
    ax = plt.subplot(projection='3d')
    ax.scatter3D(X[:, 0], X[:, 1], r, c=y, s=50, cmap='summer')
    ax.view_init(elev=elev, azim=azim)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('r')
    
interact(plot_3D, elev=(-90,90), azip=(-180,180),
        X=fixed(X), y=fixed(y));
# Out:
# interactive(children=(IntSlider(value=30, description='elev', max=90, min=-90), IntSlider(value=30, descriptio…

# %%
clf = SVC(kernel='rbf', C=1E6)
clf.fit(X, y)
# Out:
# SVC(C=1000000.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer')
plot_svc_decision_function(clf)
plt.scatter(clf.support_vectors_[:,0], clf.support_vectors_[:, 1],
           s=300, lw=1, facecolors='none')
